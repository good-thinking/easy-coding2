# %% [markdown]
# <a href="https://colab.research.google.com/github/good-thinking/easy-coding2/blob/main/ing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
from pandas import DataFrame
import numpy as np
from pandas import *
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/빅데이터 마케팅 분석 전문가_python/일일_RAWDATA(1월CSV),,,.csv", encoding= "utf-8")
df
# Out:
#        월별      광고매체         광고상품     노출수  클릭수  총전환건수★     총매출액★  간접전환건수  \
# 0     01월      구글검색      구글검색_MO    3108   96       8    408780       1
# 1     01월      구글검색      구글검색_PC    1955   61      11    482833       3
# 2     01월     네이버검색     네이버검색_MO  203676  355       3     80433       1
# 3     01월     네이버검색     네이버검색_PC   46269   88       4    205470       0
# 4     01월  네이버브랜드검색  네이버브랜드검색_MO    1355  241      37   1087605      26
# ...   ...       ...          ...     ...  ...     ...       ...     ...
# 1886  01월       GFA        설_GFA       0    0       1    110365       0
# 1887  01월       리머지        설_리머지       0    0     264  20789944       0
# 1888  01월       카울리        설_카울리       0    0      98   7313387       0
# 1889  01월    카카오모먼트  설_카카오모먼트_MO       0    0     110   7511616       0
# 1890  01월      페이스북       설_페이스북       0    0      69   5409051       0
#
#        간접매출액  직접전환건수   직접매출액  광고비_매체기준  광고비용(VAT포함)
# ...

# %%
df1 = df.dropna(axis=0)
df1
# Out:
#        월별      광고매체         광고상품     노출수  클릭수  총전환건수★     총매출액★  간접전환건수  \
# 0     01월      구글검색      구글검색_MO    3108   96       8    408780       1
# 1     01월      구글검색      구글검색_PC    1955   61      11    482833       3
# 2     01월     네이버검색     네이버검색_MO  203676  355       3     80433       1
# 3     01월     네이버검색     네이버검색_PC   46269   88       4    205470       0
# 4     01월  네이버브랜드검색  네이버브랜드검색_MO    1355  241      37   1087605      26
# ...   ...       ...          ...     ...  ...     ...       ...     ...
# 1886  01월       GFA        설_GFA       0    0       1    110365       0
# 1887  01월       리머지        설_리머지       0    0     264  20789944       0
# 1888  01월       카울리        설_카울리       0    0      98   7313387       0
# 1889  01월    카카오모먼트  설_카카오모먼트_MO       0    0     110   7511616       0
# 1890  01월      페이스북       설_페이스북       0    0      69   5409051       0
#
#        간접매출액  직접전환건수   직접매출액  광고비_매체기준  광고비용(VAT포함)
# ...

# %%
df1.columns
# Out:
# Index(['월별', '광고매체', '광고상품', '노출수', '클릭수', '총전환건수★', '총매출액★', '간접전환건수',
#        '간접매출액', '직접전환건수', '직접매출액', '광고비_매체기준', '광고비용(VAT포함)'],
#       dtype='object')

# %%
df1.boxplot(column = "총매출액★", return_type = "both")
# Out:
# BP(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f3f1fc27070>, lines={'whiskers': [<matplotlib.lines.Line2D object at 0x7f3f1fc2c850>, <matplotlib.lines.Line2D object at 0x7f3f1fc2cbb0>], 'caps': [<matplotlib.lines.Line2D object at 0x7f3f1fc2cf10>, <matplotlib.lines.Line2D object at 0x7f3f1fc471f0>], 'boxes': [<matplotlib.lines.Line2D object at 0x7f3f1fc2c4c0>], 'medians': [<matplotlib.lines.Line2D object at 0x7f3f1fc47550>], 'fliers': [<matplotlib.lines.Line2D object at 0x7f3f1fc47850>], 'means': []})
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52509 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
under_50 = df1[df1["클릭수"]<=50]
upper_50 = df1[df1["클릭수"]>50]

# %%
under_50
# Out:
#        월별      광고매체         광고상품   노출수  클릭수  총전환건수★     총매출액★  간접전환건수   간접매출액  \
# 7     01월  네이버브랜드검색  네이버브랜드검색_PC   133   19       1    517316       1  517316
# 11    01월      다음검색      다음검색_PC  2924   17       3    143845       0       0
# 42    01월      다음검색      다음검색_MO  8632   48       0         0       0       0
# 55    01월  네이버브랜드검색  네이버브랜드검색_PC   256   40       6   2470062       2  315220
# 58    01월      다음검색      다음검색_MO  9377   42       1     45053       0       0
# ...   ...       ...          ...   ...  ...     ...       ...     ...     ...
# 1886  01월       GFA        설_GFA     0    0       1    110365       0       0
# 1887  01월       리머지        설_리머지     0    0     264  20789944       0       0
# 1888  01월       카울리        설_카울리     0    0      98   7313387       0       0
# 1889  01월    카카오모먼트  설_카카오모먼트_MO     0    0     110   7511616       0       0
# 1890  01월      페이스북       설_페이스북     0    0      69   5409051       0       0
#
# ...

# %%
upper_50
# Out:
#        월별      광고매체         광고상품     노출수   클릭수  총전환건수★     총매출액★  간접전환건수  \
# 0     01월      구글검색      구글검색_MO    3108    96       8    408780       1
# 1     01월      구글검색      구글검색_PC    1955    61      11    482833       3
# 2     01월     네이버검색     네이버검색_MO  203676   355       3     80433       1
# 3     01월     네이버검색     네이버검색_PC   46269    88       4    205470       0
# 4     01월  네이버브랜드검색  네이버브랜드검색_MO    1355   241      37   1087605      26
# ...   ...       ...          ...     ...   ...     ...       ...     ...
# 1879  01월      페이스북       설_페이스북  101068  1235     412  23736986       0
# 1881  01월      크리테오     크리테오_CCA  267000   731       3     68435       0
# 1882  01월      크리테오      크리테오_LF  160638   961      97  12358389       0
# 1883  01월      페이스북         페이스북    9026   140       7    252205       0
# 1884  01월     버즈스크린        버즈스크린       0  5742       1     34716       0
#
#        간접매출액  직접전환건수   직접매출액  광고비_매체기준  광고비용(VAT포함)
# ...

# %%
df1.columns
# Out:
# Index(['월별', '광고매체', '광고상품', '노출수', '클릭수', '총전환건수★', '총매출액★', '간접전환건수',
#        '간접매출액', '직접전환건수', '직접매출액', '광고비_매체기준', '광고비용(VAT포함)'],
#       dtype='object')

# %%
x=df1[["광고매체","광고상품","노출수","클릭수","총전환건수★","총매출액★"]]
x
# Out:
#           광고매체         광고상품     노출수  클릭수  총전환건수★     총매출액★
# 0         구글검색      구글검색_MO    3108   96       8    408780
# 1         구글검색      구글검색_PC    1955   61      11    482833
# 2        네이버검색     네이버검색_MO  203676  355       3     80433
# 3        네이버검색     네이버검색_PC   46269   88       4    205470
# 4     네이버브랜드검색  네이버브랜드검색_MO    1355  241      37   1087605
# ...        ...          ...     ...  ...     ...       ...
# 1886       GFA        설_GFA       0    0       1    110365
# 1887       리머지        설_리머지       0    0     264  20789944
# 1888       카울리        설_카울리       0    0      98   7313387
# 1889    카카오모먼트  설_카카오모먼트_MO       0    0     110   7511616
# 1890      페이스북       설_페이스북       0    0      69   5409051
#
# [1891 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib-rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (7,729 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
df1["총매출액★"].hist()

# %%
from scipy import stats

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-101047ba6ec3> in <module>
# ----> 1 df1["총매출액★"].hist().describe()
#
# AttributeError: 'AxesSubplot' object has no attribute 'describe'

# %%
= 0
for i in range(1891) : 
  sum = sum + df1.iloc[i]["총매출액★"]
print(sum)
# Out:
# 5565971777

# %%
df1.columns
# Out:
# Index(['월별', '광고매체', '광고상품', '노출수', '클릭수', '총전환건수★', '총매출액★', '간접전환건수',
#        '간접매출액', '직접전환건수', '직접매출액', '광고비_매체기준', '광고비용(VAT포함)'],
#       dtype='object')

# %%
df1["광고매체"]
# Out:
# 0           구글검색
# 1           구글검색
# 2          네이버검색
# 3          네이버검색
# 4       네이버브랜드검색
#           ...
# 1886         GFA
# 1887         리머지
# 1888         카울리
# 1889      카카오모먼트
# 1890        페이스북
# Name: 광고매체, Length: 1891, dtype: object

# %%
dff = df1[["광고매체","총매출액★"]]
pd.options.display.float_format = '{:.4f}'. format
dff
# Out:
#           광고매체     총매출액★
# 0         구글검색    408780
# 1         구글검색    482833
# 2        네이버검색     80433
# 3        네이버검색    205470
# 4     네이버브랜드검색   1087605
# ...        ...       ...
# 1886       GFA    110365
# 1887       리머지  20789944
# 1888       카울리   7313387
# 1889    카카오모먼트   7511616
# 1890      페이스북   5409051
#
# [1891 rows x 2 columns]

# %%
dff= dff.dropna(axis=0)
# Out:
#           광고매체         총매출액★
# 0         구글검색   408780.0000
# 1         구글검색   482833.0000
# 2        네이버검색    80433.0000
# 3        네이버검색   205470.0000
# 4     네이버브랜드검색  1087605.0000
# ...        ...           ...
# 1886       GFA   110365.0000
# 1887       리머지 20789944.0000
# 1888       카울리  7313387.0000
# 1889    카카오모먼트  7511616.0000
# 1890      페이스북  5409051.0000
#
# [1891 rows x 2 columns]

# %%
dff.replace("구글검색",1)
# Out:
#           광고매체         총매출액★
# 0            1   408780.0000
# 1            1   482833.0000
# 2        네이버검색    80433.0000
# 3        네이버검색   205470.0000
# 4     네이버브랜드검색  1087605.0000
# ...        ...           ...
# 1886       GFA   110365.0000
# 1887       리머지 20789944.0000
# 1888       카울리  7313387.0000
# 1889    카카오모먼트  7511616.0000
# 1890      페이스북  5409051.0000
#
# [1891 rows x 2 columns]

# %%
print(txt) # A,Quick,brown,fox,jumped,over,the,lazy,dog
  txt = txt.replace(',', ' ')
  print(txt) # A Quick brown fox jumped over the lazy dog
# Out:
#   File "<ipython-input-155-b6774dcf73ea>", line 2
#     txt = txt.replace(',', ' ')
#     ^
# IndentationError: unexpected indent

# %%
dff.replace("구글검색",1).replace("네이버검색",2).replace("네이버브랜드검색",3).repalce("다음검색",4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-156-592a3dfc8fce> in <module>
# ----> 1 dff.replace("구글검색",1).replace("네이버검색",2).replace("네이버브랜드검색",3).repalce("다음검색",4)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'repalce'

# %%
dff1[dff["광고매체"] == 1] = "네이버검색"
dff
# Out:
#           광고매체         총매출액★
# 0            1             1
# 1            1             1
# 2        네이버검색    80433.0000
# 3        네이버검색   205470.0000
# 4     네이버브랜드검색  1087605.0000
# ...        ...           ...
# 1886       GFA   110365.0000
# 1887       리머지 20789944.0000
# 1888       카울리  7313387.0000
# 1889    카카오모먼트  7511616.0000
# 1890      페이스북  5409051.0000
#
# [1891 rows x 2 columns]

# %%
dff = df1[["광고매체","총매출액★"]]
dff
# Out:
#           광고매체     총매출액★
# 0         구글검색    408780
# 1         구글검색    482833
# 2        네이버검색     80433
# 3        네이버검색    205470
# 4     네이버브랜드검색   1087605
# ...        ...       ...
# 1886       GFA    110365
# 1887       리머지  20789944
# 1888       카울리   7313387
# 1889    카카오모먼트   7511616
# 1890      페이스북   5409051
#
# [1891 rows x 2 columns]

# %%
dff1=dff.replace("구글검색",1).replace("네이버검색",2).replace("네이버브랜드검색",3).replace("다음검색",4).replace("쇼핑검색",5).replace("ADN",6).replace("GFA",7).replace("UAC",8).replace("구글디스커버리",9).replace("구글디스플레이",10).replace("리머지",11).replace("모바온",12).replace("버즈빌",13).replace("버즈스크린",14).replace("카울리",15).replace("카카오모먼트",16).replace("카카오페이지",17).replace("크리테오",18).replace("페이스북",19)

# %%
dff1
# Out:
#      광고매체     총매출액★
# 0       1    408780
# 1       1    482833
# 2       2     80433
# 3       2    205470
# 4       3   1087605
# ...   ...       ...
# 1886    7    110365
# 1887   11  20789944
# 1888   15   7313387
# 1889   16   7511616
# 1890   19   5409051
#
# [1891 rows x 2 columns]

# %%
import math
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler #관측값-최솟값/ 최댓값-최솟값  # 0~1 사이에 값만 존재재
from sklearn.preprocessing import StandardScaler #평균을 0으로 만드는
from scipy.stats import boxcox

# %%
type1 = []
for i in range(1,20,1): 
    type1.append(dff1[dff1.광고매체== i].총매출액★)
sp.stats.levene(type1[0],type1[1],type1[2],type1[3],type1[4],type1[5],type1[6],type1[7],type1[8],type1[9],type1[10],type1[11],type1[12],type1[13],type1[14],type1[15],type1[16],type1[17],type1[18])
# Out:
#   File "<ipython-input-223-8322cfcb2b22>", line 3
#     type1.append(dff1[dff1.광고매체== i].총매출액★)
#                                          ^
# SyntaxError: invalid character in identifier

# %%
dff1
# Out:
#      광고매체     총매출액★
# 0       1    408780
# 1       1    482833
# 2       2     80433
# 3       2    205470
# 4       3   1087605
# ...   ...       ...
# 1886    7    110365
# 1887   11  20789944
# 1888   15   7313387
# 1889   16   7511616
# 1890   19   5409051
#
# [1891 rows x 2 columns]

# %%
type1 = []
for i in range(1,20,1) : 
    type1.append(dff1[dff1.광고매체==i].총매출액★)
# Out:
#   File "<ipython-input-213-00bb1974f525>", line 3
#     type1.append(dff1[dff1.광고매체==i].총매출액★)
#                                         ^
# SyntaxError: invalid character in identifier

# %%
dff[dff["광고매체"] == 1] = "네이버검색"
dff
# Out:
# <ipython-input-167-c80328014f6a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff[dff["광고매체"] == 1] = "네이버검색"
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#           광고매체     총매출액★
# 0         구글검색    408780
# 1         구글검색    482833
# 2        네이버검색     80433
# 3        네이버검색    205470
# 4     네이버브랜드검색   1087605
# ...        ...       ...
# 1886       GFA    110365
# ...
