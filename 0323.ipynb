# %% [markdown]
# <a href="https://colab.research.google.com/github/good-thinking/easy-coding2/blob/main/0323.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## diet 파일
# ## 종속변수 : class(다이어트 클리닉 : 1, 다이어트 식품 : 2, 다이어트 운동 : 3, 다이어트 용품 : 4)
# ## 독립변수 :  ['height', 'weight', 'want_diet','bmi', 'p_price', 'occupation', 'sex', 'married', 'created', 'upper_body(1,3,5,7,8,9)', 'lower_body(2,6)', 'face(4)', 'whole_body', 'diet_purpose', 'p_created', 'p_quantity']

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/new project/new/30_3.xlsx")
df
# Out:
#      seq_num         id  social_id1  zip_code  occupation  sex  height  \
# 0         88    3602620      710314       220           3    2   159.0
# 1        144   kwakmago      720217       135           3    2   158.0
# 2        179       SHR1      701030       480           3    2   168.0
# 3        217   jieun100      740201       139           3    2   163.0
# 4        219  altjs1972      720512       431           3    2   161.0
# ..       ...        ...         ...       ...         ...  ...     ...
# 209     1936     er1119      690705       143           3    2   160.0
# 210     1960    dangwha      711219       156           3    2   164.0
# 211     1961    dangwha      711219       156           3    2   164.0
# 212     1969    rosareo      661125       137           3    1   179.0
# 213     1980       mano      741101       411           3    2   150.0
#
#      weight  married  want_diet  ...        pfid               p_name  \
# 0      55.0        0         53  ...  PDFFUNC007          깜짝변신 다이어트세트
# 1      57.0        0         50  ...  MDEETCC013           파워스텝퍼(계측기)
# 2      53.0        0         49  ...  MDGFASH008             콘쥬르 7부바지
# 3      58.0        0         50  ...  MDGLIKE006                매직마스크
# 4      58.0        0         52  ...  PDFFUNC001          내추럴하우스 라인-업
# ..      ...      ...        ...  ...         ...                  ...
# 209    60.0        1         55  ...  PDFFUNC007          깜짝변신 다이어트세트
# 210    72.0        0         68  ...  MDEHRWE009  매직후프 디지털(계측기 포함)1세트
# 211    72.0        0         68  ...  MDGFASH004             다이어트 반바지
# 212    83.0        1         79  ...  MDEPART009            GDS-미니스텝퍼
# 213    47.0        0         46  ...  PDFFUNC001          내추럴하우스 라인-업
#
#      p_price  p_created  p_quantity    class  class.1    연도  age age group
# 0     130000          5           1  PDFFUNC        2  1971   53        50
# 1      59000          5           1  MDEETCC        3  1972   52        50
# 2      68000          5           1  MDGFASH        4  1970   54        50
# 3      24900          5           1  MDGLIKE        4  1974   50        50
# 4      60000          5           1  PDFFUNC        2  1972   52        50
# ..       ...        ...         ...      ...      ...   ...  ...       ...
# 209   130000          7           1  PDFFUNC        2  1969   55        50
# 210    27000          7           1  MDEHRWE        3  1971   53        50
# 211    29000          7           1  MDGFASH        4  1971   53        50
# 212    39900          7           1  MDEPART        3  1966   58        50
# 213    60000          7           1  PDFFUNC        2  1974   50        50
#
# [214 rows x 29 columns]

# %%
null_sum = pd.DataFrame(df.isnull().sum())
null_sum
# Out:
#                           0
# seq_num                   0
# id                        0
# social_id1                0
# zip_code                  0
# occupation                0
# sex                       0
# height                    0
# weight                    0
# married                   0
# want_diet                 0
# created                   0
# loss_part                13
# upper_body(1,3,5,7,8,9)   0
# lower_body(2,6)           0
# face(4)                   0
# whole_body                0
# diet_purpose             11
# bmi                       0
# order_id                  0
# pfid                      0
# p_name                    0
# p_price                   0
# p_created                 0
# p_quantity                0
# class                     0
# class.1                   0
# 연도                        0
# age                       0
# age group                 0

# %%
df = df.dropna(axis = 0)

# %%
df.columns
# Out:
# Index(['seq_num', 'id', 'social_id1', 'zip_code', 'occupation', 'sex',
#        'height', 'weight', 'married', 'want_diet', 'created', 'loss_part',
#        'upper_body(1,3,5,7,8,9)', 'lower_body(2,6)', 'face(4)', 'whole_body',
#        'diet_purpose', 'bmi', 'order_id', 'pfid', 'p_name', 'p_price',
#        'p_created', 'p_quantity', 'class', 'class.1', '연도', 'age',
#        'age group'],
#       dtype='object')

# %%
pd.DataFrame(df.columns)
# Out:
#                           0
# 0                   seq_num
# 1                        id
# 2                social_id1
# 3                  zip_code
# 4                occupation
# 5                       sex
# 6                    height
# 7                    weight
# 8                   married
# 9                 want_diet
# 10                  created
# 11                loss_part
# 12  upper_body(1,3,5,7,8,9)
# 13          lower_body(2,6)
# 14                  face(4)
# 15               whole_body
# 16             diet_purpose
# 17                      bmi
# 18                 order_id
# 19                     pfid
# 20                   p_name
# 21                  p_price
# 22                p_created
# 23               p_quantity
# 24                    class
# 25                  class.1
# 26                       연도
# 27                      age
# 28                age group

# %%
df = df.drop([df.columns[0], df.columns[1], df.columns[2], df.columns[11], df.columns[18]], axis = 1)

# %%
numeric_list = [df.columns[3], df.columns[4], df.columns[6],df.columns[13], df.columns[16]]

# %%
numeric_df = df[numeric_list]

# %%
cg_list = df.drop(numeric_list, axis = 1)

# %%
cg_list
# Out:
#      zip_code  occupation  sex  married  created  upper_body(1,3,5,7,8,9)  \
# 0         220           3    2        0        1                        1
# 1         135           3    2        0        4                        1
# 2         480           3    2        0        1                        1
# 3         139           3    2        0        2                        1
# 4         431           3    2        0        3                        1
# ..        ...         ...  ...      ...      ...                      ...
# 209       143           3    2        1        3                        1
# 210       156           3    2        0        4                        1
# 211       156           3    2        0        4                        1
# 212       137           3    1        1        1                        1
# 213       411           3    2        0        4                        1
#
#      lower_body(2,6)  face(4)  whole_body  diet_purpose        pfid  \
# 0                  1        0           0           1.0  PDFFUNC007
# 1                  1        0           0           2.0  MDEETCC013
# 2                  1        0           0           1.0  MDGFASH008
# 3                  0        1           0           2.0  MDGLIKE006
# 4                  1        0           0           5.0  PDFFUNC001
# ..               ...      ...         ...           ...         ...
# 209                0        0           0           1.0  PDFFUNC007
# 210                0        0           0           2.0  MDEHRWE009
# 211                0        0           0           2.0  MDGFASH004
# 212                1        0           0           1.0  MDEPART009
# 213                1        0           0           1.0  PDFFUNC001
#
#                   p_name  p_created  p_quantity    class  class.1    연도  age  \
# 0            깜짝변신 다이어트세트          5           1  PDFFUNC        2  1971   53
# 1             파워스텝퍼(계측기)          5           1  MDEETCC        3  1972   52
# 2               콘쥬르 7부바지          5           1  MDGFASH        4  1970   54
# 3                  매직마스크          5           1  MDGLIKE        4  1974   50
# 4            내추럴하우스 라인-업          5           1  PDFFUNC        2  1972   52
# ..                   ...        ...         ...      ...      ...   ...  ...
# 209          깜짝변신 다이어트세트          7           1  PDFFUNC        2  1969   55
# 210  매직후프 디지털(계측기 포함)1세트          7           1  MDEHRWE        3  1971   53
# 211             다이어트 반바지          7           1  MDGFASH        4  1971   53
# 212            GDS-미니스텝퍼          7           1  MDEPART        3  1966   58
# 213          내추럴하우스 라인-업          7           1  PDFFUNC        2  1974   50
#
#      age group
# 0           50
# 1           50
# 2           50
# 3           50
# 4           50
# ..         ...
# 209         50
# 210         50
# 211         50
# 212         50
# 213         50
#
# [200 rows x 19 columns]

# %%
pd.DataFrame(cg_list.columns)
# Out:
#                           0
# 0                  zip_code
# 1                occupation
# 2                       sex
# 3                   married
# 4                   created
# 5   upper_body(1,3,5,7,8,9)
# 6           lower_body(2,6)
# 7                   face(4)
# 8                whole_body
# 9              diet_purpose
# 10                     pfid
# 11                   p_name
# 12                p_created
# 13               p_quantity
# 14                    class
# 15                  class.1
# 16                       연도
# 17                      age
# 18                age group

# %%
cg_list = cg_list.drop([cg_list.columns[10], cg_list.columns[11], cg_list.columns[14], cg_list.columns[15]], axis = 1)

# %%
cg_list_df = cg_list

# %%
cg_list_df = cg_list_df.drop(["zip_code"], axis = 1)

# %%
cg_list_df.columns
# Out:
# Index(['occupation', 'sex', 'married', 'created', 'upper_body(1,3,5,7,8,9)',
#        'lower_body(2,6)', 'face(4)', 'whole_body', 'diet_purpose', 'p_created',
#        'p_quantity', '연도', 'age', 'age group'],
#       dtype='object')

# %%
cg_list = ['occupation', 'sex', 'married', 'created', 'upper_body(1,3,5,7,8,9)',
       'lower_body(2,6)', 'face(4)', 'whole_body', 'diet_purpose', 'p_created',
       'p_quantity']

# %%
X = df[numeric_list + cg_list]

# %%
X.columns
# Out:
# Index(['height', 'weight', 'want_diet', 'bmi', 'p_price', 'occupation', 'sex',
#        'married', 'created', 'upper_body(1,3,5,7,8,9)', 'lower_body(2,6)',
#        'face(4)', 'whole_body', 'diet_purpose', 'p_created', 'p_quantity'],
#       dtype='object')

# %%
Y = df[df.columns[20]]

# %%
pd.DataFrame(Y)
# Out:
#      class.1
# 0          2
# 1          3
# 2          4
# 3          4
# 4          2
# ..       ...
# 209        2
# 210        3
# 211        4
# 212        3
# 213        2
#
# [200 rows x 1 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# %%
ct = ColumnTransformer([("scaling", StandardScaler(), numeric_list), 
                        ("onehot", OneHotEncoder(sparse = False), cg_list)])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train,Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

selector = SelectFromModel(RandomForestClassifier(n_estimators = 100, random_state=0), threshold = "median")
selector.fit(X_train, Y_train)

score = pd.DataFrame()
score["attribute"] = X_train.columns
score["support"] =  selector.get_support()
score[score["support"] == True]
# Out:
#        attribute  support
# 0         height     True
# 1         weight     True
# 2      want_diet     True
# 3            bmi     True
# 4        p_price     True
# 8        created     True
# 13  diet_purpose     True
# 14     p_created     True

,1,3\n150.0,47.0,46,21,18000,3,2,0,4,1,1,0,0,1.0,7,1,1\n164.0,72.0,68,26,18000,3,2,0,4,1,0,0,0,2.0,7,1,1\n160.0,50.0,46,19,35000,3,2,0,2,0,1,0,0,5.0,7,1,3\n163.0,60.0,56,22,130000,3,2,0,2,1,1,0,0,1.0,7,1,2\n163.0,60.0,56,22,260000,3,2,0,2,1,1,0,0,1.0,7,2,2\n159.0,57.0,52,22,60000,3,2,1,2,1,1,0,0,1.0,7,1,2\n172.0,85.0,70,28,52000,3,1,1,2,1,1,0,0,3.0,7,1,3\n167.0,54.0,50,19,12900,3,2,0,3,1,1,1,1,1.0,8,1,4\n179.0,83.0,79,25,18000,3,1,1, ...

# %%
col_name = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/new project/new/30_3_colname.csv", encoding = "cp949")
col_name
# Out:
#     Unnamed: 0          colnames.X_train.
# 0            1                     height
# 1            2                     weight
# 2            3                  want_diet
# 3            4                        bmi
# 4            5                    p_price
# 5            6               occupation_3
# 6            7                      sex_1
# 7            8                      sex_2
# 8            9                  married_0
# 9           10                  married_1
# 10          11                  created_1
# 11          12                  created_2
# 12          13                  created_3
# 13          14                  created_4
# 14          15  upper_body(1,3,5,7,8,9)_0
# 15          16  upper_body(1,3,5,7,8,9)_1
# 16          17          lower_body(2,6)_0
# 17          18          lower_body(2,6)_1
# 18          19                  face(4)_0
# 19          20                  face(4)_1
# 20          21               whole_body_0
# 21          22               whole_body_1
# 22          23             diet_purpose_1
# 23          24             diet_purpose_2
# 24          25             diet_purpose_3
# 25          26             diet_purpose_4
# 26          27             diet_purpose_5
# 27          28                p_created_5
# 28          29                p_created_6
# 29          30                p_created_7
# 30          31                p_created_8
# 31          32               p_quantity_0
# 32          33               p_quantity_1
# 33          34               p_quantity_2
# 34          35               p_quantity_3

# %%
ct.fit(X)
X_train = ct.transform(X_train)
X_test = ct.transform(X_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from imblearn.over_sampling import SMOTE #synthetic minority over-sampling technique
from collections import Counter

X_train_over, Y_train_over = SMOTE(random_state = 0).fit_resample(X_train, Y_train)

print("original data %s" % Counter(Y))
print("original train data %s" % Counter(Y_train))
print("over train data %s" % Counter(Y_train_over))
# Out:
# original data Counter({4: 72, 3: 67, 2: 40, 1: 21})
# original train data Counter({3: 52, 4: 50, 2: 24, 1: 14})
# over train data Counter({4: 52, 3: 52, 2: 52, 1: 52})

# %%
X_train, Y_train = X_train_over, Y_train_over

# %%
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression(C = 1, random_state = 0)

logit.fit(X_train, Y_train)
Y_pred = logit.predict(X_test)

print("R2 : {:.3f}" .format(logit.score(X_train, Y_train)))

from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
print(logit.intercept_)
print(logit.coef_)
# Out:
# R2 : 0.808
#               precision    recall  f1-score   support
#
#            1       0.40      0.57      0.47         7
#            2       0.62      0.31      0.42        16
#            3       0.35      0.60      0.44        15
#            4       0.50      0.36      0.42        22
#
#     accuracy                           0.43        60
#    3.81133374e-01 -3.85009610e-01 -3.90155818e-01  3.86279583e-01
#   -5.73954384e-01  5.70078149e-01 -6.74941630e-01  4.15426407e-01
#   -6.43871892e-01  7.70756271e-01  1.28754608e-01  1.37507449e+00
#   -6.93984552e-02 -4.09721261e-01 -8.99831012e-01  1.54453877e-01
#   -5.09709250e-01  4.99068362e-01 -1.47689225e-01]]

# %%
coefficient2 = model2.coef_

# %%
transposed_array2 = np.transpose(pd.DataFrame(coefficient2))

# %%
transposed_array2[4] = col_name["colnames.X_train."]

# %%
transposed_array2
# Out:
#            0         1         2         3                          4
# 0  -0.224329 -0.406486 -0.215820  0.846635                     height
# 1  -0.798697 -0.023338  0.600276  0.221759                     weight
# 2   0.826404 -0.057254 -0.134247 -0.634903                  want_diet
# 3   0.715715 -0.485232 -0.125090 -0.105393                        bmi
# 4   1.994775  1.683438 -1.135145 -2.543068                    p_price
# 5  -0.003990  0.005332  0.002534 -0.003876               occupation_3
# 6  -0.823498  0.389873  0.238164  0.195461                      sex_1
# 7   0.819508 -0.384541 -0.235630 -0.199337                      sex_2
# 8   0.113798 -0.190582  0.153198 -0.076414                  married_0
# 9  -0.117789  0.195915 -0.150664  0.072538                  married_1
# 10 -0.092757 -0.120211  0.191265  0.021703                  created_1
# 11 -0.075794 -0.197750  0.215461  0.058083                  created_2
# 12 -0.677007  0.087434  0.201399  0.388173                  created_3
# 13  0.841567  0.235859 -0.605590 -0.471836                  created_4
# 14 -0.639929 -0.134127  0.363583  0.410472  upper_body(1,3,5,7,8,9)_0
# 15  0.635939  0.139459 -0.361049 -0.414348  upper_body(1,3,5,7,8,9)_1
# 16 -0.601647  0.192918  0.027596  0.381133          lower_body(2,6)_0
# 17  0.597657 -0.187585 -0.025062 -0.385010          lower_body(2,6)_1
# 18  0.929321  0.034714 -0.573879 -0.390156                  face(4)_0
# 19 -0.933311 -0.029382  0.576413  0.386280                  face(4)_1
# 20  0.675366 -0.298778  0.197366 -0.573954               whole_body_0
# 21 -0.679356  0.304110 -0.194832  0.570078               whole_body_1
# 22 -0.179437  0.572575  0.281803 -0.674942             diet_purpose_1
# 23  0.197992 -0.349071 -0.264347  0.415426             diet_purpose_2
# 24 -0.001790 -0.084260  0.729921 -0.643872             diet_purpose_3
# 25 -0.479154  0.493338 -0.784940  0.770756             diet_purpose_4
# 26  0.458399 -0.627251  0.040098  0.128755             diet_purpose_5
# 27 -0.827255 -0.299750 -0.248070  1.375074                p_created_5
# 28 -0.124736 -0.611659  0.805793 -0.069398                p_created_6
# 29 -0.296738  0.475172  0.231288 -0.409721                p_created_7
# 30  1.244739  0.441569 -0.786477 -0.899831                p_created_8
# 31 -0.095709 -0.130990  0.072245  0.154454               p_quantity_0
# 32  0.804225  0.225178 -0.519694 -0.509709               p_quantity_1
# 33 -0.711498 -0.068888  0.281318  0.499068               p_quantity_2
# 34 -0.001008 -0.019969  0.168666 -0.147689               p_quantity_3
