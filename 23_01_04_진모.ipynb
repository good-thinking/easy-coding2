# %% [markdown]
# <a href="https://colab.research.google.com/github/good-thinking/easy-coding2/blob/main/23_01_04_%EC%A7%84%EB%AA%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df= pd.read_csv("/content/drive/MyDrive/일일_RAWDATA(1월CSV).csv")
df
# Out:
#         월별      광고매체         광고상품  구분2  구분3       노출수    클릭수  총전환건수★  \
# 0      01월      구글검색      구글검색_MO  NaN  NaN    3108.0   96.0     8.0
# 1      01월      구글검색      구글검색_PC  NaN  NaN    1955.0   61.0    11.0
# 2      01월     네이버검색     네이버검색_MO  NaN  NaN  203676.0  355.0     3.0
# 3      01월     네이버검색     네이버검색_PC  NaN  NaN   46269.0   88.0     4.0
# 4      01월  네이버브랜드검색  네이버브랜드검색_MO  NaN  NaN    1355.0  241.0    37.0
# ...    ...       ...          ...  ...  ...       ...    ...     ...
# 23335  NaN       NaN          NaN  NaN  NaN       NaN    NaN     NaN
# 23336  NaN       NaN          NaN  NaN  NaN       NaN    NaN     NaN
# 23337  NaN       NaN          NaN  NaN  NaN       NaN    NaN     NaN
# 23338  NaN       NaN          NaN  NaN  NaN       NaN    NaN     NaN
# 23339  NaN       NaN          NaN  NaN  NaN       NaN    NaN     NaN
#
#            총매출액★  간접전환건수     간접매출액  직접전환건수     직접매출액  광고비_매체기준  광고비용(VAT포함)
# ...

# %%
df.boxplot(column="총전환건수★",return_type="both")
# Out:
# BP(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f8f7991b940>, lines={'whiskers': [<matplotlib.lines.Line2D object at 0x7f8f799095e0>, <matplotlib.lines.Line2D object at 0x7f8f79909940>], 'caps': [<matplotlib.lines.Line2D object at 0x7f8f79909ca0>, <matplotlib.lines.Line2D object at 0x7f8f798ac040>], 'boxes': [<matplotlib.lines.Line2D object at 0x7f8f79909280>], 'medians': [<matplotlib.lines.Line2D object at 0x7f8f798ac3a0>], 'fliers': [<matplotlib.lines.Line2D object at 0x7f8f798ac6a0>], 'means': []})
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52509 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
df["총전환건수★"].hist()

# %%
q1=df["총전환건수★"].quantile(q=0.25)
q3=df["총전환건수★"].quantile(q=0.75)
IQR=q3-q1
IQR
# Out:
# 28.0

# %%
data_IQR=df_qq[(df_qq["총전환건수★"]<q3+IQR*1.5)&(df_qq["총전환건수★"]>q1-IQR*1.5)]

# %%
data_IQR
# Out:
#         월별      광고매체         광고상품  구분2  구분3       노출수     클릭수  총전환건수★  \
# 0      01월      구글검색      구글검색_MO  NaN  NaN    3108.0    96.0     8.0
# 1      01월      구글검색      구글검색_PC  NaN  NaN    1955.0    61.0    11.0
# 2      01월     네이버검색     네이버검색_MO  NaN  NaN  203676.0   355.0     3.0
# 3      01월     네이버검색     네이버검색_PC  NaN  NaN   46269.0    88.0     4.0
# 4      01월  네이버브랜드검색  네이버브랜드검색_MO  NaN  NaN    1355.0   241.0    37.0
# ...    ...       ...          ...  ...  ...       ...     ...     ...
# 10207  01월      페이스북         페이스북   매체   일반    9026.0   140.0     7.0
# 10208  01월     버즈스크린        버즈스크린   매체   일반       0.0  5742.0     1.0
# 10209  01월    카카오페이지       카카오페이지   매체   일반       0.0     0.0     0.0
# 10210  01월       GFA        설_GFA  브랜치    설       0.0     0.0     1.0
# 10214  01월      페이스북       설_페이스북  브랜치    설       0.0     0.0    69.0
#
#            총매출액★  간접전환건수     간접매출액  직접전환건수     직접매출액   광고비_매체기준  광고비용(VAT포함)
# ...

# %%
data_IQR["총전환건수★"].hist()

# %%
data_outlier=df[(df["총전환건수★"]>q3+IQR*1.5)]
data_outlier
# Out:
#         월별     광고매체         광고상품  구분2  구분3       노출수      클릭수  총전환건수★  \
# 72     01월  네이버쇼핑검색   네이버쇼핑검색_MO  NaN  NaN  117633.0   2046.0    80.0
# 88     01월  네이버쇼핑검색   네이버쇼핑검색_MO  NaN  NaN  109071.0   1962.0    86.0
# 93     01월      모비온       모비온_PC  NaN  NaN  483798.0   9757.0   124.0
# 109    01월      모비온       모비온_PC  NaN  NaN  458444.0   9905.0   107.0
# 124    01월      모비온       모비온_MO  NaN  NaN  744555.0  15186.0    75.0
# ...    ...      ...          ...  ...  ...       ...      ...     ...
# 10203  01월     페이스북       설_페이스북   매체    설  101068.0   1235.0   412.0
# 10206  01월     크리테오      크리테오_LF   매체   일반  160638.0    961.0    97.0
# 10211  01월      리머지        설_리머지  브랜치    설       0.0      0.0   264.0
# 10212  01월      카울리        설_카울리  브랜치    설       0.0      0.0    98.0
# 10213  01월   카카오모먼트  설_카카오모먼트_MO  브랜치    설       0.0      0.0   110.0
#
#             총매출액★  간접전환건수       간접매출액  직접전환건수      직접매출액   광고비_매체기준  \
# ...

# %%
data_outlier["총전환건수★"].hist()

# %%
data_outlier=df[(df["총전환건수★"]<q1-IQR*1.5)]
data_outlier
# Out:
# Empty DataFrame
# Columns: [월별, 광고매체, 광고상품, 구분2, 구분3, 노출수, 클릭수, 총전환건수★, 총매출액★, 간접전환건수, 간접매출액, 직접전환건수, 직접매출액, 광고비_매체기준, 광고비용(VAT포함)]
# Index: []

# %%
import pandas as pd
df= pd.read_csv("/content/drive/MyDrive/일일_RAWDATA(1월CSV).csv")
df
# Out:
#         월별      광고매체         광고상품  구분2  구분3       노출수    클릭수  총전환건수★  \
# 0      01월      구글검색      구글검색_MO  NaN  NaN    3108.0   96.0     8.0
# 1      01월      구글검색      구글검색_PC  NaN  NaN    1955.0   61.0    11.0
# 2      01월     네이버검색     네이버검색_MO  NaN  NaN  203676.0  355.0     3.0
# 3      01월     네이버검색     네이버검색_PC  NaN  NaN   46269.0   88.0     4.0
# 4      01월  네이버브랜드검색  네이버브랜드검색_MO  NaN  NaN    1355.0  241.0    37.0
# ...    ...       ...          ...  ...  ...       ...    ...     ...
# 23335  NaN       NaN          NaN  NaN  NaN       NaN    NaN     NaN
# 23336  NaN       NaN          NaN  NaN  NaN       NaN    NaN     NaN
# 23337  NaN       NaN          NaN  NaN  NaN       NaN    NaN     NaN
# 23338  NaN       NaN          NaN  NaN  NaN       NaN    NaN     NaN
# 23339  NaN       NaN          NaN  NaN  NaN       NaN    NaN     NaN
#
#            총매출액★  간접전환건수     간접매출액  직접전환건수     직접매출액  광고비_매체기준  광고비용(VAT포함)
# ...

# %%
df.describe()
# Out:
#                 노출수            클릭수       총전환건수★         총매출액★       간접전환건수  \
# count  1.891000e+03    1891.000000  1891.000000  1.891000e+03  1891.000000
# mean   6.484336e+04    3760.725013    42.141724  2.943401e+06     7.162348
# std    1.405802e+05   16041.988197   148.303842  7.794651e+06    21.286794
# min    0.000000e+00       0.000000     0.000000  0.000000e+00     0.000000
# 25%    8.845000e+02      38.000000     1.000000  3.427150e+04     0.000000
# 50%    6.963000e+03     173.000000     7.000000  4.644990e+05     0.000000
# 75%    6.550850e+04     620.500000    29.000000  2.348454e+06     3.000000
# max    1.307190e+06  130000.000000  2748.000000  1.142274e+08   240.000000
#
#               간접매출액       직접전환건수         직접매출액      광고비_매체기준   광고비용(VAT포함)
# count  1.891000e+03  1891.000000  1.891000e+03  1.891000e+03  1.891000e+03
# mean   6.302209e+05    16.604442  1.147512e+06  1.596496e+05  1.743400e+05
# ...

# %%
df.columns
# Out:
# Index(['월별', '광고매체', '광고상품', '구분2', '구분3', '노출수', '클릭수', '총전환건수★', '총매출액★',
#        '간접전환건수', '간접매출액', '직접전환건수', '직접매출액', '광고비_매체기준', '광고비용(VAT포함)'],
#       dtype='object')

# %%
under=df[df["노출수"]<=97181]
upper=df[df["노출수"]>97181]

print(under)
print(upper)
# Out:
#         월별      광고매체         광고상품  구분2  구분3      노출수    클릭수  총전환건수★  \
# 0      01월      구글검색      구글검색_MO  NaN  NaN   3108.0   96.0     8.0
# 1      01월      구글검색      구글검색_PC  NaN  NaN   1955.0   61.0    11.0
# 3      01월     네이버검색     네이버검색_PC  NaN  NaN  46269.0   88.0     4.0
# 4      01월  네이버브랜드검색  네이버브랜드검색_MO  NaN  NaN   1355.0  241.0    37.0
# 5      01월  네이버브랜드검색  네이버브랜드검색_MO  NaN  NaN   1361.0   92.0     1.0
# ...    ...       ...          ...  ...  ...      ...    ...     ...
# 10210  01월       GFA        설_GFA  브랜치    설      0.0    0.0     1.0
# 10211  01월       리머지        설_리머지  브랜치    설      0.0    0.0   264.0
# 10212  01월       카울리        설_카울리  브랜치    설      0.0    0.0    98.0
# 10213  01월    카카오모먼트  설_카카오모먼트_MO  브랜치    설      0.0    0.0   110.0
# 10214  01월      페이스북       설_페이스북  브랜치    설      0.0    0.0    69.0
#
#             총매출액★  간접전환건수     간접매출액  직접전환건수     직접매출액  광고비_매체기준  광고비용(VAT포함)
# ...

# %%
under.head()
# Out:
#     월별      광고매체         광고상품  구분2  구분3      노출수    클릭수  총전환건수★      총매출액★  \
# 0  01월      구글검색      구글검색_MO  NaN  NaN   3108.0   96.0     8.0   408780.0
# 1  01월      구글검색      구글검색_PC  NaN  NaN   1955.0   61.0    11.0   482833.0
# 3  01월     네이버검색     네이버검색_PC  NaN  NaN  46269.0   88.0     4.0   205470.0
# 4  01월  네이버브랜드검색  네이버브랜드검색_MO  NaN  NaN   1355.0  241.0    37.0  1087605.0
# 5  01월  네이버브랜드검색  네이버브랜드검색_MO  NaN  NaN   1361.0   92.0     1.0    57651.0
#
#    간접전환건수     간접매출액  직접전환건수     직접매출액  광고비_매체기준  광고비용(VAT포함)
# 0     1.0   17983.0     7.0  390797.0   43942.0      55587.0
# 1     3.0  172205.0     8.0  310628.0  104159.0     131761.0
# 3     0.0       0.0     4.0  205470.0   52107.0      52107.0
# 4    26.0  588423.0    11.0  499182.0  128400.0     128400.0
# 5     0.0       0.0     1.0   57651.0   36590.0      36590.0

# %%
upper.head()
# Out:
#      월별   광고매체      광고상품  구분2  구분3       노출수      클릭수  총전환건수★      총매출액★  \
# 2   01월  네이버검색  네이버검색_MO  NaN  NaN  203676.0    355.0     3.0    80433.0
# 12  01월    모비온    모비온_MO  NaN  NaN  845819.0  16546.0    37.0  1624597.0
# 13  01월    모비온    모비온_PC  NaN  NaN  318608.0   7615.0    29.0  1288781.0
# 18  01월  네이버검색  네이버검색_MO  NaN  NaN  172012.0    359.0     5.0   590474.0
# 28  01월    모비온    모비온_MO  NaN  NaN  727428.0  14944.0    64.0  2145010.0
#
#     간접전환건수      간접매출액  직접전환건수     직접매출액  광고비_매체기준  광고비용(VAT포함)
# 2      1.0    15996.0     2.0   64437.0  157685.0     157685.0
# 12    31.0  1268132.0     6.0  356465.0  309589.0     340548.0
# 13    22.0   892019.0     7.0  396762.0  150037.0     165041.0
# 18     0.0        0.0     5.0  590474.0  164637.0     164637.0
# 28    43.0  1336771.0    21.0  808239.0  289035.0     317939.0

# %%
df_join=under.append(upper)
print(df_join)
# Out:
#         월별      광고매체         광고상품  구분2  구분3       노출수     클릭수  총전환건수★  \
# 0      01월      구글검색      구글검색_MO  NaN  NaN    3108.0    96.0     8.0
# 1      01월      구글검색      구글검색_PC  NaN  NaN    1955.0    61.0    11.0
# 3      01월     네이버검색     네이버검색_PC  NaN  NaN   46269.0    88.0     4.0
# 4      01월  네이버브랜드검색  네이버브랜드검색_MO  NaN  NaN    1355.0   241.0    37.0
# 5      01월  네이버브랜드검색  네이버브랜드검색_MO  NaN  NaN    1361.0    92.0     1.0
# ...    ...       ...          ...  ...  ...       ...     ...     ...
# 10201  01월       카울리        설_카울리   매체    설  498913.0  4350.0     1.0
# 10202  01월    카카오모먼트  설_카카오모먼트_MO   매체    설  770693.0  2086.0    56.0
# 10203  01월      페이스북       설_페이스북   매체    설  101068.0  1235.0   412.0
# 10205  01월      크리테오     크리테오_CCA   매체   일반  267000.0   731.0     3.0
# 10206  01월      크리테오      크리테오_LF   매체   일반  160638.0   961.0    97.0
#
#             총매출액★  간접전환건수      간접매출액  직접전환건수      직접매출액   광고비_매체기준  \
# ...

# %%
df_join.describe()
# Out:
#                 노출수            클릭수       총전환건수★         총매출액★       간접전환건수  \
# count  1.891000e+03    1891.000000  1891.000000  1.891000e+03  1891.000000
# mean   6.484336e+04    3760.725013    42.141724  2.943401e+06     7.162348
# std    1.405802e+05   16041.988197   148.303842  7.794651e+06    21.286794
# min    0.000000e+00       0.000000     0.000000  0.000000e+00     0.000000
# 25%    8.845000e+02      38.000000     1.000000  3.427150e+04     0.000000
# 50%    6.963000e+03     173.000000     7.000000  4.644990e+05     0.000000
# 75%    6.550850e+04     620.500000    29.000000  2.348454e+06     3.000000
# max    1.307190e+06  130000.000000  2748.000000  1.142274e+08   240.000000
#
#               간접매출액       직접전환건수         직접매출액      광고비_매체기준   광고비용(VAT포함)
# count  1.891000e+03  1891.000000  1.891000e+03  1.891000e+03  1.891000e+03
# mean   6.302209e+05    16.604442  1.147512e+06  1.596496e+05  1.743400e+05
# ...

# %%
y=df_join[["노출수","클릭수"]]
x=df_join[["간접전환건수","클릭수","간접매출액","직접매출액"]]

# %%
y=pd.DataFrame(y)
x=pd.DataFrame(x)

# %%
xy_merge=y.merge(x)
xy_merge
# Out:
#             노출수     클릭수  간접전환건수      간접매출액      직접매출액
# 0        3108.0    96.0     1.0    17983.0   390797.0
# 1        3108.0    96.0     2.0   267616.0        0.0
# 2        3108.0    96.0     0.0        0.0        0.0
# 3        3108.0    96.0     0.0        0.0        0.0
# 4         899.0    96.0     1.0    17983.0   390797.0
# ...         ...     ...     ...        ...        ...
# 89606  295495.0  3645.0     1.0     8991.0        0.0
# 89607  498913.0  4350.0     1.0    23572.0        0.0
# 89608  770693.0  2086.0    37.0  2238599.0  1674324.0
# 89609  101068.0  1235.0     0.0        0.0        0.0
# 89610  160638.0   961.0     0.0        0.0        0.0
#
# [89611 rows x 5 columns]

# %%
xy_merge.plot.scatter(x="노출수",y="직접매출액",title="aaa")
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51649 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('font',family='NanumBarunGothic')

# %%
from pandas.errors import InvalidIndexError
# %matplotlib Inline
xy_merge.plot.scatter(x="노출수",y="직접매출액",title="aaa")

plt.legend()
plt.grid()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
